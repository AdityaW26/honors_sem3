# %%
# packages to store and manipulate data
import pandas as pd
import numpy as np

# plotting packages
import matplotlib.pyplot as plt
import seaborn as sns

# model building package
import sklearn

# package to clean text
import re

# %%
df = pd.read_csv('climate_tweets.csv')
df.head()
# Out:
#                                                tweet
# 0  Global warming report urges governments to act...
# 1  Fighting poverty and global warming in Africa ...
# 2  Carbon offsets: How a Vatican forest failed to...
# 3  Carbon offsets: How a Vatican forest failed to...
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...

# %% [markdown]
# <h4>Exploratory Data Analysis</h4>

# %%
# shape of dataset
print('Shape of dataset = ',df.shape)
# shape of unique elems in dataset
print('Shape of dataset with unique tweets = ',df.tweet.unique().shape)
# Out:
# Shape of dataset =  (6090, 1)
# Shape of dataset with unique tweets =  (5541,)

# %%
# make a new column to highlight retweets
df['is_retweet'] = df['tweet'].apply(lambda x: x[:2]=='RT')
df['is_retweet'].sum()  # number of retweets
# Out:
# 773

# %%
df.head()
# Out:
#                                                tweet  is_retweet
# 0  Global warming report urges governments to act...       False
# 1  Fighting poverty and global warming in Africa ...       False
# 2  Carbon offsets: How a Vatican forest failed to...       False
# 3  Carbon offsets: How a Vatican forest failed to...       False
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       False

# %%
# 10 most repeated tweets
df.groupby(['tweet']).size().reset_index(name='counts')\
  .sort_values('counts', ascending=False).head(10)
# Out:
#                                                   tweet  counts
# 3131  No matter if you believe in global warming or ...      20
# 4555  Take Action @change: Help Protect Wildlife Hab...      14
# 4027  RT @newtgingrich: Historic snow storm in washi...       9
# 1765       Fight Climate Change From All Fronts: [link]       8
# 1626  Earth's polar ice sheets vulnerable to even mo...       7
# 1941  Global Warming Dent's El Ni'o's Protective Shi...       7
# 1799  Foes of California's global warming law pour m...       6
# 1351  Coalition of the Tired of Waiting: Fighting Cl...       6
# 4271  SCIENCE: Scientists explore the evolution of c...       6
# 1040  Carbon offsets: How a Vatican forest failed to...       6

# %%
# number of times each tweet appears
counts = df.groupby(['tweet']).size()\
           .reset_index(name='counts')\
           .counts

# define bins for histogram
my_bins = np.arange(0,counts.max()+2, 1)-0.5

# plot histogram of tweet counts
plt.figure()
plt.hist(counts, bins = my_bins)
plt.xlabels = np.arange(1,counts.max()+1, 1)
plt.xlabel('copies of each tweet')
plt.ylabel('frequency')
plt.yscale('log', nonposy='clip')
plt.show()
# Out:
# C:\Users\Lenovo\.conda\envs\myenv\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   from ipykernel import kernelapp as app

# %% [markdown]
# <h4>Extracting substrings with regex</h4>

# %%
def find_retweeted(tweet):
    '''This function will extract the twitter handles of retweed people'''
    return re.findall('(?<=RT\s)(@[A-Za-z]+[A-Za-z0-9-_]+)', tweet)

def find_mentioned(tweet):
    '''This function will extract the twitter handles of people mentioned in the tweet'''
    return re.findall('(?<!RT\s)(@[A-Za-z]+[A-Za-z0-9-_]+)', tweet)  

def find_hashtags(tweet):
    '''This function will extract hashtags'''
    return re.findall('(#[A-Za-z]+[A-Za-z0-9-_]+)', tweet)

# %%
# make new columns for retweeted usernames, mentioned usernames and hashtags
df['retweeted'] = df.tweet.apply(find_retweeted)
df['mentioned'] = df.tweet.apply(find_mentioned)
df['hashtags'] = df.tweet.apply(find_hashtags)

# %%
df
# Out:
#                                                   tweet  is_retweet retweeted  \
# 0     Global warming report urges governments to act...       False        []
# 1     Fighting poverty and global warming in Africa ...       False        []
# 2     Carbon offsets: How a Vatican forest failed to...       False        []
# 3     Carbon offsets: How a Vatican forest failed to...       False        []
# 4     URUGUAY: Tools Needed for Those Most Vulnerabl...       False        []
# ...                                                 ...         ...       ...
# 6085  @bloodless_coup "The phrase 'global warming' s...       False        []
# 6086  Virginia to Investigate Global Warming Scienti...       False        []
# 6087  Global warming you tube parody you will enjoy ...       False        []
# 6088  One-Eyed Golfer: Don't dare tell me about glob...       False        []
# 6089  man made global warming a hair brained theory ...       False        []
#
#               mentioned                    hashtags
# 0                    []                          []
# 1                    []                          []
# 2                    []                          []
# 3                    []                          []
# 4                    []                          []
# ...                 ...                         ...
# 6085  [@bloodless_coup]                [#p2, #tcot]
# 6086                 []                          []
# 6087                 []              [#IPCC, #ocra]
# 6088                 []                          []
# 6089                 []  [#tcot, #p2, #climategate]
#
# [6090 rows x 5 columns]

# %% [markdown]
# <h4>Hashtag Analysis</h4>

# %%
# take the rows from the hashtag columns where there are actually hashtags
hashtags_list_df = df.loc[
                       df.hashtags.apply(
                           lambda hashtags_list: hashtags_list !=[]
                       ),['hashtags']]

# %%
hashtags_list_df
# Out:
#                                                hashtags
# 12                              [#Climate, #population]
# 16                                          [#EarthDay]
# 26                                                [#ac]
# 31                                              [#tcot]
# 36    [#tornadocot, #ocra, #sgp, #gop, #ucot, #tlot,...
# ...                                                 ...
# 6076                    [#liberalFascism, #News, #tcot]
# 6083                                         [#climate]
# 6085                                       [#p2, #tcot]
# 6087                                     [#IPCC, #ocra]
# 6089                         [#tcot, #p2, #climategate]
#
# [1129 rows x 1 columns]

# %%
# create dataframe where each use of hashtag gets its own row
flattened_hashtags_df = pd.DataFrame(
    [hashtag for hashtags_list in hashtags_list_df.hashtags
    for hashtag in hashtags_list],
    columns=['hashtag'])

# %%
flattened_hashtags_df
# Out:
#            hashtag
# 0         #Climate
# 1      #population
# 2        #EarthDay
# 3              #ac
# 4            #tcot
# ...            ...
# 2062         #IPCC
# 2063         #ocra
# 2064         #tcot
# 2065           #p2
# 2066  #climategate
#
# [2067 rows x 1 columns]

# %%
# number of unique hashtags
flattened_hashtags_df['hashtag'].unique().size
# Out:
# 477

# %%
# count of appearances of each hashtag
popular_hashtags = flattened_hashtags_df.groupby('hashtag').size()\
                                        .reset_index(name='counts')\
                                        .sort_values('counts', ascending=False)\
                                        .reset_index(drop=True)

# %%
popular_hashtags
# Out:
#             hashtag  counts
# 0             #tcot     227
# 1          #climate     202
# 2               #p2     112
# 3            #green      50
# 4    #climatechange      47
# ..              ...     ...
# 472           #home       1
# 473           #hoth       1
# 474        #houston       1
# 475    #humanrights       1
# 476           #digg       1
#
# [477 rows x 2 columns]

# %%
# number of times each hashtag appears
counts = flattened_hashtags_df.groupby(['hashtag']).size()\
                              .reset_index(name='counts')\
                              .counts

# define bins for histogram                              
my_bins = np.arange(0,counts.max()+2, 5)-0.5

# plot histogram of tweet counts
plt.figure()
plt.hist(counts, bins = my_bins)
plt.xlabels = np.arange(1,counts.max()+1, 1)
plt.xlabel('hashtag number of appearances')
plt.ylabel('frequency')
plt.yscale('log', nonposy='clip')
plt.show()
# Out:
# C:\Users\Lenovo\.conda\envs\myenv\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   from ipykernel import kernelapp as app

# %% [markdown]
# <h4>Vectorization</h4>

# %%
# taking hashtags which appear at least this amount of times
min_appearance = 10
# find popular hashtags - make into python set for efficiency
popular_hashtags_set = set(popular_hashtags[
                           popular_hashtags.counts>=min_appearance
                           ]['hashtag'])

# %%
# make a new column with only the popular hashtags
hashtags_list_df['popular_hashtags'] = hashtags_list_df.hashtags.apply(
            lambda hashtag_list: [hashtag for hashtag in hashtag_list
                                  if hashtag in popular_hashtags_set])
# drop rows without popular hashtag
popular_hashtags_list_df = hashtags_list_df.loc[
            hashtags_list_df.popular_hashtags.apply(lambda hashtag_list: hashtag_list !=[])]

# %%
# make new dataframe
hashtag_vector_df = popular_hashtags_list_df.loc[:, ['popular_hashtags']]

for hashtag in popular_hashtags_set:
    # make columns to encode presence of hashtags
    hashtag_vector_df['{}'.format(hashtag)] = hashtag_vector_df.popular_hashtags.apply(
        lambda hashtag_list: int(hashtag in hashtag_list))

# %%
hashtag_vector_df
# Out:
#                      popular_hashtags  #EarthDay  #SaveTerra  #cleantech  #fb  \
# 12                         [#Climate]          0           0           0    0
# 16                        [#EarthDay]          1           0           0    0
# 31                            [#tcot]          0           0           0    0
# 36    [#ocra, #sgp, #gop, #tlot, #p2]          0           0           0    0
# 39                       [#tcot, #p2]          0           0           0    0
# ...                               ...        ...         ...         ...  ...
# 6076                   [#News, #tcot]          0           0           0    0
# 6083                       [#climate]          0           0           0    0
# 6085                     [#p2, #tcot]          0           0           0    0
# 6087                   [#IPCC, #ocra]          0           0           0    0
# 6089       [#tcot, #p2, #climategate]          0           0           0    0
#
#       #UN  #global  #Green  #climategate  #ocra  ...  #SierraClub  #sgp  \
# 12      0        0       0             0      0  ...            0     0
# 16      0        0       0             0      0  ...            0     0
# 31      0        0       0             0      0  ...            0     0
# 36      0        0       0             0      1  ...            0     1
# 39      0        0       0             0      0  ...            0     0
# ...   ...      ...     ...           ...    ...  ...          ...   ...
# 6076    0        0       0             0      0  ...            0     0
# 6083    0        0       0             0      0  ...            0     0
# 6085    0        0       0             0      0  ...            0     0
# 6087    0        0       0             0      1  ...            0     0
# 6089    0        0       0             1      0  ...            0     0
#
#       #TCOT  #News  #earthday  #agw  #GlobalWarming  #tlot  #teaparty  #du1
# 12        0      0          0     0               0      0          0     0
# 16        0      0          0     0               0      0          0     0
# 31        0      0          0     0               0      0          0     0
# 36        0      0          0     0               0      1          0     0
# 39        0      0          0     0               0      0          0     0
# ...     ...    ...        ...   ...             ...    ...        ...   ...
# 6076      0      1          0     0               0      0          0     0
# 6083      0      0          0     0               0      0          0     0
# 6085      0      0          0     0               0      0          0     0
# 6087      0      0          0     0               0      0          0     0
# 6089      0      0          0     0               0      0          0     0
#
# [786 rows x 36 columns]

# %%
hashtag_matrix = hashtag_vector_df.drop('popular_hashtags', axis=1)

# %%
hashtag_matrix
# Out:
#       #EarthDay  #SaveTerra  #cleantech  #fb  #UN  #global  #Green  \
# 12            0           0           0    0    0        0       0
# 16            1           0           0    0    0        0       0
# 31            0           0           0    0    0        0       0
# 36            0           0           0    0    0        0       0
# 39            0           0           0    0    0        0       0
# ...         ...         ...         ...  ...  ...      ...     ...
# 6076          0           0           0    0    0        0       0
# 6083          0           0           0    0    0        0       0
# 6085          0           0           0    0    0        0       0
# 6087          0           0           0    0    0        0       0
# 6089          0           0           0    0    0        0       0
#
#       #climategate  #ocra  #p2  ...  #SierraClub  #sgp  #TCOT  #News  \
# 12               0      0    0  ...            0     0      0      0
# 16               0      0    0  ...            0     0      0      0
# 31               0      0    0  ...            0     0      0      0
# 36               0      1    1  ...            0     1      0      0
# 39               0      0    1  ...            0     0      0      0
# ...            ...    ...  ...  ...          ...   ...    ...    ...
# 6076             0      0    0  ...            0     0      0      1
# 6083             0      0    0  ...            0     0      0      0
# 6085             0      0    1  ...            0     0      0      0
# 6087             0      1    0  ...            0     0      0      0
# 6089             1      0    1  ...            0     0      0      0
#
#       #earthday  #agw  #GlobalWarming  #tlot  #teaparty  #du1
# 12            0     0               0      0          0     0
# 16            0     0               0      0          0     0
# 31            0     0               0      0          0     0
# 36            0     0               0      1          0     0
# 39            0     0               0      0          0     0
# ...         ...   ...             ...    ...        ...   ...
# 6076          0     0               0      0          0     0
# 6083          0     0               0      0          0     0
# 6085          0     0               0      0          0     0
# 6087          0     0               0      0          0     0
# 6089          0     0               0      0          0     0
#
# [786 rows x 35 columns]

# %%
# calculate the correlation matrix
correlations = hashtag_matrix.corr()

# plot the correlation matrix
plt.figure(figsize=(10,10))
sns.heatmap(correlations,
    cmap='RdBu',
    vmin=-1,
    vmax=1,
    square = True,
    cbar_kws={'label':'correlation'})
plt.show()

# %% [markdown]
# <h6>From the plot above we can see that there are fairly strong correlations between:
#
# 1)SaveTerra and #SierraClub
#
# 2)GloablWarming and #FoxNews
#
# We can also see a fairly strong negative correlation between:
#
# 1)tcot and #climate</h6>

# %% [markdown]
# <h4>Topic Modelling</h4>

# %% [markdown]
# <h5>Cleaning the unstructured text data</h5>

# %%
# !pip install nltk
import nltk
nltk.download('stopwords')
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
# Out:
# Requirement already satisfied: nltk in c:\users\lenovo\.conda\envs\myenv\lib\site-packages (3.6.7)
# Requirement already satisfied: tqdm in c:\users\lenovo\.conda\envs\myenv\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in c:\users\lenovo\.conda\envs\myenv\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in c:\users\lenovo\.conda\envs\myenv\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lenovo\.conda\envs\myenv\lib\site-packages (from nltk) (2022.9.13)
# Requirement already satisfied: importlib-metadata in c:\users\lenovo\.conda\envs\myenv\lib\site-packages (from click->nltk) (4.8.3)
# Requirement already satisfied: colorama in c:\users\lenovo\.conda\envs\myenv\lib\site-packages (from click->nltk) (0.4.5)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\lenovo\.conda\envs\myenv\lib\site-packages (from importlib-metadata->click->nltk) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\.conda\envs\myenv\lib\site-packages (from importlib-metadata->click->nltk) (3.6.0)
# Requirement already satisfied: importlib-resources in c:\users\lenovo\.conda\envs\myenv\lib\site-packages (from tqdm->nltk) (5.4.0)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_links(tweet):
    '''Takes a string and removes web links from it'''
    tweet = re.sub(r'http\S+', '', tweet) # remove http links
    tweet = re.sub(r'bit.ly/\S+', '', tweet) # rempve bitly links
    tweet = tweet.strip('[link]') # remove [links]
    return tweet

def remove_users(tweet):
    '''Takes a string and removes retweet and @user information'''
    tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet
    tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove tweeted at
    return tweet

# %%
my_stopwords = nltk.corpus.stopwords.words('english')
word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
my_punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@'

# cleaning master function
def clean_tweet(tweet, bigrams=False):
    tweet = remove_users(tweet)
    tweet = remove_links(tweet)
    tweet = tweet.lower() # lower case
    tweet = re.sub('['+my_punctuation + ']+', ' ', tweet) # strip punctuation
    tweet = re.sub('\s+', ' ', tweet) #remove double spacing
    tweet = re.sub('([0-9]+)', '', tweet) # remove numbers
    tweet_token_list = [word for word in tweet.split(' ')
                            if word not in my_stopwords] # remove stopwords

    tweet_token_list = [word_rooter(word) if '#' not in word else word
                        for word in tweet_token_list] # apply word rooter
    if bigrams:
        tweet_token_list = tweet_token_list+[tweet_token_list[i]+'_'+tweet_token_list[i+1]
                                            for i in range(len(tweet_token_list)-1)]
    tweet = ' '.join(tweet_token_list)
    return tweet

# %%
df['clean_tweet'] = df.tweet.apply(clean_tweet)

# %%
df
# Out:
#                                                   tweet  is_retweet retweeted  \
# 0     Global warming report urges governments to act...       False        []
# 1     Fighting poverty and global warming in Africa ...       False        []
# 2     Carbon offsets: How a Vatican forest failed to...       False        []
# 3     Carbon offsets: How a Vatican forest failed to...       False        []
# 4     URUGUAY: Tools Needed for Those Most Vulnerabl...       False        []
# ...                                                 ...         ...       ...
# 6085  @bloodless_coup "The phrase 'global warming' s...       False        []
# 6086  Virginia to Investigate Global Warming Scienti...       False        []
# 6087  Global warming you tube parody you will enjoy ...       False        []
# 6088  One-Eyed Golfer: Don't dare tell me about glob...       False        []
# 6089  man made global warming a hair brained theory ...       False        []
#
#               mentioned                    hashtags  \
# 0                    []                          []
# 1                    []                          []
# 2                    []                          []
# 3                    []                          []
# 4                    []                          []
# ...                 ...                         ...
# 6085  [@bloodless_coup]                [#p2, #tcot]
# 6086                 []                          []
# 6087                 []              [#IPCC, #ocra]
# 6088                 []                          []
# 6089                 []  [#tcot, #p2, #climategate]
#
#                                             clean_tweet
# 0     global warm report urg govern act brussel belg...
# 1                     fight poverti global warm africa
# 2     carbon offset vatican forest fail reduc global...
# 3     carbon offset vatican forest fail reduc global...
# 4                uruguay tool need vulner climat chang
# ...                                                 ...
# 6085   phrase global warm abandon favor climat chang...
# 6086      virginia investig global warm scientist mann
# 6087         global warm tube parodi enjoy #ipcc #ocra
# 6088  one eye golfer dare tell global warm twenti fi...
# 6089  man made global warm hair brain theori  scient...
#
# [6090 rows x 6 columns]

# %% [markdown]
#  <h5>Applying Topic Modelling</h5>

# %%
from sklearn.feature_extraction.text import CountVectorizer

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')

# apply transformation
tf = vectorizer.fit_transform(df['clean_tweet']).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()

# %%
from sklearn.decomposition import LatentDirichletAllocation

# chosen arbitrarily
number_of_topics = 10

model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

# %%
model.fit(tf)
# Out:
# LatentDirichletAllocation(random_state=0)

# %%
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

# %%
no_top_words = 10
display_topics(model, tf_feature_names, no_top_words)
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0        climat          1220.2        global           666.5        global
# 1         chang          1184.5          warm           658.1          warm
# 2           via           257.9          snow           160.5     scientist
# 3        scienc           112.9         #tcot           121.6           say
# 4          news            79.5          like            99.0        scienc
# 5           day            77.8      blizzard            90.9         debat
# 6         earth            68.2            dc            86.5           man
# 7         trial            68.1         think            83.3          made
# 8        clinic            68.1           due            80.1          show
# 9        carbon            64.5          make            70.4         water
#
#   Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words Topic 4 weights  \
# 0          1147.2        global           473.1        climat           422.0
# 1          1102.1          warm           450.7         chang           401.8
# 2           150.2        believ           101.3        legisl           123.2
# 3            87.1    california            87.1            us           105.1
# 4            71.7         blame            82.1           via            60.5
# 5            66.6           law            78.6           say            55.9
# 6            61.1        report            77.8         video            55.9
# 7            54.0          save            61.8         place            54.1
# 8            51.9         money            56.1          good            52.6
# 9            50.6          live            49.3         human            48.2
#
#   Topic 5 words Topic 5 weights Topic 6 words Topic 6 weights Topic 7 words  \
# 0        global           783.0         chang           666.1          warm
# 1          warm           764.7        climat           661.6      #climate
# 2          gore           137.1        energi           178.8       volcano
# 3          snow           123.7             u           109.8        global
# 4            al           122.1           via            96.5         chang
# 5         great            94.1        nation            89.0          help
# 6          cold            77.1          make            74.5          take
# 7          call            76.5        impact            67.5        climat
# 8         #tcot            75.3        report            63.4       iceland
# 9           one            72.1          issu            58.8         could
#
#   Topic 7 weights Topic 8 words Topic 8 weights Topic 9 words Topic 9 weights
# 0           167.9        climat           568.3        climat           529.9
# 1           139.2         chang           550.5         chang           520.6
# 2           128.9           new           321.1         peopl           153.4
# 3           128.6          bill           116.9         world           151.3
# 4           122.0         senat           106.1        confer           110.1
# 5           114.1         agenc            95.1          bill           106.4
# 6            96.8        immigr            77.7          talk            94.8
# 7            76.7         obama            75.6        graham            92.1
# 8            67.1         feder            67.1            un            77.6
# 9            64.5           via            58.6           put            68.8

# %%
topic_df = display_topics(model, tf_feature_names, no_top_words)
topic_df.shape
# Out:
# (10, 20)

# %%
topic_df
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0        climat          1220.2        global           666.5        global
# 1         chang          1184.5          warm           658.1          warm
# 2           via           257.9          snow           160.5     scientist
# 3        scienc           112.9         #tcot           121.6           say
# 4          news            79.5          like            99.0        scienc
# 5           day            77.8      blizzard            90.9         debat
# 6         earth            68.2            dc            86.5           man
# 7         trial            68.1         think            83.3          made
# 8        clinic            68.1           due            80.1          show
# 9        carbon            64.5          make            70.4         water
#
#   Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words Topic 4 weights  \
# 0          1147.2        global           473.1        climat           422.0
# 1          1102.1          warm           450.7         chang           401.8
# 2           150.2        believ           101.3        legisl           123.2
# 3            87.1    california            87.1            us           105.1
# 4            71.7         blame            82.1           via            60.5
# 5            66.6           law            78.6           say            55.9
# 6            61.1        report            77.8         video            55.9
# 7            54.0          save            61.8         place            54.1
# 8            51.9         money            56.1          good            52.6
# 9            50.6          live            49.3         human            48.2
#
#   Topic 5 words Topic 5 weights Topic 6 words Topic 6 weights Topic 7 words  \
# 0        global           783.0         chang           666.1          warm
# 1          warm           764.7        climat           661.6      #climate
# 2          gore           137.1        energi           178.8       volcano
# 3          snow           123.7             u           109.8        global
# 4            al           122.1           via            96.5         chang
# 5         great            94.1        nation            89.0          help
# 6          cold            77.1          make            74.5          take
# 7          call            76.5        impact            67.5        climat
# 8         #tcot            75.3        report            63.4       iceland
# 9           one            72.1          issu            58.8         could
#
#   Topic 7 weights Topic 8 words Topic 8 weights Topic 9 words Topic 9 weights
# 0           167.9        climat           568.3        climat           529.9
# 1           139.2         chang           550.5         chang           520.6
# 2           128.9           new           321.1         peopl           153.4
# 3           128.6          bill           116.9         world           151.3
# 4           122.0         senat           106.1        confer           110.1
# 5           114.1         agenc            95.1          bill           106.4
# 6            96.8        immigr            77.7          talk            94.8
# 7            76.7         obama            75.6        graham            92.1
# 8            67.1         feder            67.1            un            77.6
# 9            64.5           via            58.6           put            68.8
